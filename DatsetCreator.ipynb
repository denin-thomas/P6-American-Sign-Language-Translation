# %%
import cv2
import numpy as np
import mediapipe as mp
import os
from datetime import datetime

# Configuration
SAVE_FOLDER = "asl_dataset_right_hand"  # Folder to save images
os.makedirs(SAVE_FOLDER, exist_ok=True)  # Create folder if it doesn't exist

# Initialize MediaPipe
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=False,
                       max_num_hands=1,
                       min_detection_confidence=0.5,
                       min_tracking_confidence=0.5)

mp_drawing = mp.solutions.drawing_utils

def draw_hand_landmarks_diagram(hand_landmarks, image_size=128, padding_factor=0.3):
    """Create a clean hand landmark diagram with white lines on black background"""
    landmarks = np.array([[lm.x, lm.y] for lm in hand_landmarks.landmark])
    
    # Calculate bounds with padding
    x_vals = landmarks[:, 0]
    y_vals = landmarks[:, 1]
    width = np.max(x_vals) - np.min(x_vals)
    height = np.max(y_vals) - np.min(y_vals)
    
    pad_x = width * padding_factor
    pad_y = height * padding_factor
    
    min_x = np.min(x_vals) - pad_x
    max_x = np.max(x_vals) + pad_x
    min_y = np.min(y_vals) - pad_y
    max_y = np.max(y_vals) + pad_y
    
    # Normalize to image size
    hand_width = max_x - min_x
    hand_height = max_y - min_y
    scale = image_size / max(hand_width, hand_height) * 0.9
    
    landmarks[:, 0] = (landmarks[:, 0] - min_x) * scale
    landmarks[:, 1] = (landmarks[:, 1] - min_y) * scale
    
    # Center in image
    offset_x = (image_size - (hand_width * scale)) / 2
    offset_y = (image_size - (hand_height * scale)) / 2
    landmarks[:, 0] += offset_x
    landmarks[:, 1] += offset_y
    
    # Create black canvas
    diagram = np.zeros((image_size, image_size), dtype=np.uint8)
    points = landmarks.astype(np.int32)
    
    # Draw connections (white lines)
    for connection in mp_hands.HAND_CONNECTIONS:
        start = tuple(points[connection[0]])
        end = tuple(points[connection[1]])
        cv2.line(diagram, start, end, 255, 1)
    
    # Draw landmarks (white points)
    for point in points:
        cv2.circle(diagram, tuple(point), 1, 255, -1)
    
    return diagram

# Start webcam
cap = cv2.VideoCapture(0)
save_counter = 0

print("ASL Dataset Creation Tool")
print("Press:")
print("- 's' to save current hand diagram")
print("- '1-9' to set current class label")
print("- ESC to exit")

current_label = "A"  # Default label

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hands.process(rgb_frame)

    # Display current label
    cv2.putText(frame, f"Current label: {current_label}", (10, 30), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
    cv2.putText(frame, f"Saved: {save_counter}", (10, 60), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Create the diagram
            diagram = draw_hand_landmarks_diagram(hand_landmarks)
            
            # Show preview
            cv2.imshow("Diagram Preview", diagram)
            
            # Draw landmarks on webcam feed
            mp_drawing.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)
            break

    cv2.imshow("ASL Dataset Creator", frame)

    key = cv2.waitKey(1)
    if key & 0xFF == 27:  # ESC key
        break
    elif key == ord('a') and results.multi_hand_landmarks:
        # Save the diagram
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S_%f")
        filename = f"{SAVE_FOLDER}/{current_label}_{timestamp}.png"
        cv2.imwrite(filename, diagram)
        save_counter += 1
        print(f"Saved {filename}")
    elif ord('1') <= key <= ord('9'):
        # Change label (1=A, 2=B, ..., 9=I)
        current_label = chr(ord('A') + (key - ord('1')))
    elif key == ord('0'):
        # Set label to J (0 key)
        current_label = 'J'
    elif ord('a') <= key <= ord('z'):
        # Change label to pressed letter
        current_label = chr(key).upper()

cap.release()
cv2.destroyAllWindows()
# Out:
# ASL Dataset Creation Tool
# Press:
# - 's' to save current hand diagram
# - '1-9' to set current class label
# - ESC to exit
# Saved asl_dataset_right_hand/A_20250607_122308_923046.png
# Saved asl_dataset_right_hand/A_20250607_122309_243606.png
# Saved asl_dataset_right_hand/A_20250607_122309_515281.png
# Saved asl_dataset_right_hand/A_20250607_122309_700453.png
# Saved asl_dataset_right_hand/A_20250607_122309_946120.png
# Saved asl_dataset_right_hand/A_20250607_122310_138727.png
# Saved asl_dataset_right_hand/A_20250607_122310_395125.png
# Saved asl_dataset_right_hand/A_20250607_122310_620593.png
# Saved asl_dataset_right_hand/A_20250607_122310_859235.png
# Saved asl_dataset_right_hand/A_20250607_122311_083517.png
# Saved asl_dataset_right_hand/A_20250607_122311_339417.png
# Saved asl_dataset_right_hand/A_20250607_122311_547858.png
# Saved asl_dataset_right_hand/A_20250607_122311_724618.png
# Saved asl_dataset_right_hand/A_20250607_122311_906205.png
# Saved asl_dataset_right_hand/A_20250607_122312_172410.png
# Saved asl_dataset_right_hand/A_20250607_122312_394314.png
# Saved asl_dataset_right_hand/A_20250607_122312_650883.png
# Saved asl_dataset_right_hand/A_20250607_122312_843462.png
# Saved asl_dataset_right_hand/A_20250607_122313_009872.png
# Saved asl_dataset_right_hand/A_20250607_122313_164842.png
# Saved asl_dataset_right_hand/A_20250607_122313_340366.png
# Saved asl_dataset_right_hand/A_20250607_122313_484355.png
# Saved asl_dataset_right_hand/A_20250607_122313_660589.png
# Saved asl_dataset_right_hand/A_20250607_122313_868436.png
# Saved asl_dataset_right_hand/A_20250607_122314_047763.png
# Saved asl_dataset_right_hand/A_20250607_122314_236486.png
# Saved asl_dataset_right_hand/A_20250607_122314_396302.png
# Saved asl_dataset_right_hand/A_20250607_122314_572505.png
# Saved asl_dataset_right_hand/A_20250607_122314_748157.png
# Saved asl_dataset_right_hand/A_20250607_122314_924371.png
# Saved asl_dataset_right_hand/A_20250607_122315_148400.png
# Saved asl_dataset_right_hand/A_20250607_122315_340610.png
# Saved asl_dataset_right_hand/A_20250607_122315_563960.png
# Saved asl_dataset_right_hand/A_20250607_122315_852478.png
# Saved asl_dataset_right_hand/A_20250607_122316_043446.png
# Saved asl_dataset_right_hand/A_20250607_122316_204421.png
# Saved asl_dataset_right_hand/A_20250607_122316_380527.png
# Saved asl_dataset_right_hand/A_20250607_122316_572396.png
# Saved asl_dataset_right_hand/A_20250607_122316_763223.png
# Saved asl_dataset_right_hand/A_20250607_122316_990919.png
# Saved asl_dataset_right_hand/A_20250607_122317_212336.png
# Saved asl_dataset_right_hand/A_20250607_122317_422014.png
# Saved asl_dataset_right_hand/A_20250607_122317_612613.png
# Saved asl_dataset_right_hand/A_20250607_122317_788261.png
# Saved asl_dataset_right_hand/A_20250607_122317_964863.png
# Saved asl_dataset_right_hand/A_20250607_122318_156555.png
# Saved asl_dataset_right_hand/A_20250607_122318_347488.png
# Saved asl_dataset_right_hand/A_20250607_122318_587480.png
# Saved asl_dataset_right_hand/A_20250607_122318_779444.png
# Saved asl_dataset_right_hand/A_20250607_122318_971302.png
# Saved asl_dataset_right_hand/A_20250607_122319_164226.png
# Saved asl_dataset_right_hand/A_20250607_122319_356567.png
# Saved asl_dataset_right_hand/A_20250607_122319_563437.png
# Saved asl_dataset_right_hand/A_20250607_122319_852509.png
# Saved asl_dataset_right_hand/A_20250607_122320_029940.png
# Saved asl_dataset_right_hand/A_20250607_122320_236644.png
# Saved asl_dataset_right_hand/A_20250607_122320_395435.png
# Saved asl_dataset_right_hand/A_20250607_122320_555440.png
# Saved asl_dataset_right_hand/A_20250607_122320_779703.png
# Saved asl_dataset_right_hand/A_20250607_122320_940739.png
# Saved asl_dataset_right_hand/A_20250607_122321_196606.png
# Saved asl_dataset_right_hand/A_20250607_122321_422437.png
# Saved asl_dataset_right_hand/A_20250607_122321_612324.png
# Saved asl_dataset_right_hand/A_20250607_122321_819963.png
# Saved asl_dataset_right_hand/A_20250607_122322_124188.png
# Saved asl_dataset_right_hand/A_20250607_122322_348722.png
# Saved asl_dataset_right_hand/A_20250607_122322_526474.png
# Saved asl_dataset_right_hand/A_20250607_122322_715414.png
# Saved asl_dataset_right_hand/A_20250607_122322_922892.png
# Saved asl_dataset_right_hand/A_20250607_122323_135111.png
# Saved asl_dataset_right_hand/A_20250607_122323_340528.png
# Saved asl_dataset_right_hand/A_20250607_122323_500470.png
# Saved asl_dataset_right_hand/A_20250607_122323_740418.png
# Saved asl_dataset_right_hand/A_20250607_122323_931168.png
# Saved asl_dataset_right_hand/A_20250607_122324_140671.png
# Saved asl_dataset_right_hand/A_20250607_122324_363820.png
# Saved asl_dataset_right_hand/A_20250607_122324_572479.png
# Saved asl_dataset_right_hand/A_20250607_122324_764224.png
# Saved asl_dataset_right_hand/A_20250607_122324_972316.png
# Saved asl_dataset_right_hand/A_20250607_122325_180344.png
# Saved asl_dataset_right_hand/A_20250607_122325_372703.png
# Saved asl_dataset_right_hand/A_20250607_122325_580607.png
# Saved asl_dataset_right_hand/A_20250607_122325_755946.png
# Saved asl_dataset_right_hand/A_20250607_122325_948295.png
# Saved asl_dataset_right_hand/A_20250607_122326_108549.png
# Saved asl_dataset_right_hand/A_20250607_122326_300223.png
# Saved asl_dataset_right_hand/A_20250607_122326_570681.png
# Saved asl_dataset_right_hand/A_20250607_122326_764364.png
# Saved asl_dataset_right_hand/A_20250607_122326_988261.png
# Saved asl_dataset_right_hand/A_20250607_122327_180198.png
# Saved asl_dataset_right_hand/A_20250607_122327_355198.png
# Saved asl_dataset_right_hand/A_20250607_122327_547385.png
# Saved asl_dataset_right_hand/A_20250607_122327_724534.png
# Saved asl_dataset_right_hand/A_20250607_122327_964187.png
# Saved asl_dataset_right_hand/A_20250607_122328_156608.png
# Saved asl_dataset_right_hand/A_20250607_122328_348522.png
# Saved asl_dataset_right_hand/A_20250607_122328_556351.png
# Saved asl_dataset_right_hand/A_20250607_122328_779223.png
# Saved asl_dataset_right_hand/A_20250607_122328_972307.png
# Saved asl_dataset_right_hand/A_20250607_122329_196469.png
# Saved asl_dataset_right_hand/A_20250607_122329_436194.png
# Saved asl_dataset_right_hand/A_20250607_122329_628401.png
# Saved asl_dataset_right_hand/A_20250607_122329_820495.png
# Saved asl_dataset_right_hand/A_20250607_122330_012309.png
# Saved asl_dataset_right_hand/A_20250607_122330_248049.png
# Saved asl_dataset_right_hand/A_20250607_122330_427409.png
# Saved asl_dataset_right_hand/A_20250607_122330_636673.png
# Saved asl_dataset_right_hand/A_20250607_122330_844425.png
# Saved asl_dataset_right_hand/A_20250607_122331_048702.png
# Saved asl_dataset_right_hand/A_20250607_122331_228532.png
# Saved asl_dataset_right_hand/A_20250607_122331_436571.png
# Saved asl_dataset_right_hand/A_20250607_122331_596087.png
# Saved asl_dataset_right_hand/A_20250607_122331_739084.png
# Saved asl_dataset_right_hand/A_20250607_122331_883360.png
# Saved asl_dataset_right_hand/A_20250607_122332_090786.png
# Saved asl_dataset_right_hand/A_20250607_122332_364337.png
# Saved asl_dataset_right_hand/A_20250607_122332_603605.png
# Saved asl_dataset_right_hand/A_20250607_122332_795003.png
# Saved asl_dataset_right_hand/A_20250607_122332_987227.png
# Saved asl_dataset_right_hand/A_20250607_122333_195073.png
# Saved asl_dataset_right_hand/A_20250607_122333_356280.png
# Saved asl_dataset_right_hand/A_20250607_122333_580100.png
# Saved asl_dataset_right_hand/A_20250607_122333_804559.png
# Saved asl_dataset_right_hand/A_20250607_122333_980460.png
# Saved asl_dataset_right_hand/A_20250607_122334_204408.png
# Saved asl_dataset_right_hand/A_20250607_122335_932349.png
# Saved asl_dataset_right_hand/A_20250607_122336_140223.png
# Saved asl_dataset_right_hand/A_20250607_122336_316230.png
# Saved asl_dataset_right_hand/A_20250607_122336_478254.png
# Saved asl_dataset_right_hand/A_20250607_122336_668770.png
# Saved asl_dataset_right_hand/A_20250607_122336_875002.png
# Saved asl_dataset_right_hand/A_20250607_122337_068649.png
# Saved asl_dataset_right_hand/A_20250607_122337_276105.png
# Saved asl_dataset_right_hand/A_20250607_122337_484430.png
# Saved asl_dataset_right_hand/A_20250607_122337_660561.png
# Saved asl_dataset_right_hand/A_20250607_122337_883605.png
# Saved asl_dataset_right_hand/A_20250607_122338_140342.png
# Saved asl_dataset_right_hand/A_20250607_122338_367748.png
# Saved asl_dataset_right_hand/A_20250607_122338_558748.png
# Saved asl_dataset_right_hand/A_20250607_122338_732256.png
# Saved asl_dataset_right_hand/A_20250607_122338_924333.png
# Saved asl_dataset_right_hand/A_20250607_122339_148173.png
# Saved asl_dataset_right_hand/A_20250607_122339_340167.png
# Saved asl_dataset_right_hand/A_20250607_122339_570364.png
# Saved asl_dataset_right_hand/A_20250607_122339_760915.png
# Saved asl_dataset_right_hand/A_20250607_122340_012495.png
# Saved asl_dataset_right_hand/A_20250607_122340_235375.png
# Saved asl_dataset_right_hand/A_20250607_122340_428514.png
# Saved asl_dataset_right_hand/A_20250607_122340_668242.png
# Saved asl_dataset_right_hand/A_20250607_122340_907484.png
# Saved asl_dataset_right_hand/A_20250607_122341_115905.png
# Saved asl_dataset_right_hand/A_20250607_122341_355273.png
# Saved asl_dataset_right_hand/A_20250607_122341_612136.png
# Saved asl_dataset_right_hand/A_20250607_122341_836454.png
# Saved asl_dataset_right_hand/A_20250607_122342_092771.png
# Saved asl_dataset_right_hand/A_20250607_122342_312309.png
# Saved asl_dataset_right_hand/A_20250607_122342_522993.png
# Saved asl_dataset_right_hand/A_20250607_122342_702704.png
# Saved asl_dataset_right_hand/A_20250607_122342_892242.png
# Saved asl_dataset_right_hand/A_20250607_122343_099012.png
# Saved asl_dataset_right_hand/A_20250607_122343_372613.png
# Saved asl_dataset_right_hand/A_20250607_122343_596730.png
# Saved asl_dataset_right_hand/A_20250607_122343_804511.png
# Saved asl_dataset_right_hand/A_20250607_122343_996674.png
# Saved asl_dataset_right_hand/A_20250607_122344_220182.png
# Saved asl_dataset_right_hand/A_20250607_122344_443629.png
# Saved asl_dataset_right_hand/A_20250607_122344_667217.png
# Saved asl_dataset_right_hand/A_20250607_122344_907423.png
# Saved asl_dataset_right_hand/A_20250607_122345_131254.png
# Saved asl_dataset_right_hand/A_20250607_122345_371243.png
# Saved asl_dataset_right_hand/A_20250607_122345_599291.png
# Saved asl_dataset_right_hand/A_20250607_122345_868082.png
# Saved asl_dataset_right_hand/A_20250607_122346_124196.png
# Saved asl_dataset_right_hand/A_20250607_122346_350790.png
# Saved asl_dataset_right_hand/A_20250607_122346_591004.png
# Saved asl_dataset_right_hand/A_20250607_122346_795350.png
# Saved asl_dataset_right_hand/A_20250607_122347_004663.png
# Saved asl_dataset_right_hand/A_20250607_122347_212229.png
# Saved asl_dataset_right_hand/A_20250607_122347_454493.png
# Saved asl_dataset_right_hand/A_20250607_122347_658429.png
# Saved asl_dataset_right_hand/A_20250607_122347_855350.png
# Saved asl_dataset_right_hand/A_20250607_122348_047499.png
# Saved asl_dataset_right_hand/A_20250607_122348_267281.png
# Saved asl_dataset_right_hand/A_20250607_122348_474733.png
# Saved asl_dataset_right_hand/A_20250607_122348_684320.png
# Saved asl_dataset_right_hand/A_20250607_122348_876067.png
# Saved asl_dataset_right_hand/A_20250607_122349_099429.png
# Saved asl_dataset_right_hand/A_20250607_122349_322858.png
# Saved asl_dataset_right_hand/A_20250607_122349_516403.png
# Saved asl_dataset_right_hand/A_20250607_122349_722856.png
# Saved asl_dataset_right_hand/A_20250607_122349_931504.png
# Saved asl_dataset_right_hand/A_20250607_122350_123978.png
# Saved asl_dataset_right_hand/A_20250607_122350_332457.png
# Saved asl_dataset_right_hand/A_20250607_122350_540377.png
# Saved asl_dataset_right_hand/A_20250607_122350_780330.png
# Saved asl_dataset_right_hand/A_20250607_122350_971428.png
# Saved asl_dataset_right_hand/A_20250607_122351_180627.png
# Saved asl_dataset_right_hand/A_20250607_122351_404545.png
# Saved asl_dataset_right_hand/A_20250607_122351_644287.png
# Saved asl_dataset_right_hand/A_20250607_122352_044536.png
